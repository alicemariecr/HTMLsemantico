# %% [markdown]
# <a href="https://colab.research.google.com/github/alicemariecr/HTMLsemantico/blob/main/Hello_wold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello wold!!")
# Out:
# Hello wold!!

# %%
idade = 15     #int
altura = 1.66    #float
numero_complexo = 2 + 3j
esta_chovendo = false

# %%
lado = 10
quadrado = lado * lado
print (f"total da área do quadrado: {quadrado}" )
# Out:
# total da área do quadrado: 100

# %%
largura = 5
altura = 4
area = largura * altura
print (f"total da área: {area}" )
# Out:
# total da área: 20

# %%
largura = float(input("A medida da largura: "))
altura = float(input("A medida da altura: "))
area = largura * altura
print(f"total da área: {area}")
# Out:
# A medida da largura: 6
# A medida da altura: 2
# total da área: 12.0

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite sua segunda nota: "))
nota3 = float(input("Digite sua terceira nota: "))
nota4 = float(input("Digite sua quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4)/4
print (media)
# Out:
# Digite a primeira nota: 10
# Digite sua segunda nota: 8.5
# Digite sua terceira nota: 9
# Digite sua quarta nota: 9.5
# 9.25

# %%
numero1 = float(input("Digite o número: "))
dobro = numero1 * 2
print (dobro)
# Out:
# Digite o número: 5
# 10.0
